# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#multiple value assigners
a = ("darshan",25,"Aws data engg",100000)

# %%
name,age,role,salary = a

# %%
salary
# Out:
# 100000

# %%
x= 3+4j
print(x.real)
print(x.imag)
# Out:
# 3.0
# 4.0

# %%
# Best method of opening the file in python
with open ("testing.txt",'r') as f:
    print(f.readlines())
# Out:
# ['Hi this is darshan\n', "I'am an AWS Data Engineer"]
